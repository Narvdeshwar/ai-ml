# %%
import json

# %%
# load data
def load_Data(file_name,mode):
    with open(file_name,mode) as f:
        data=json.load(f)
    return data

# %%
data=load_Data("store_data.json","r")

# %%
for user in data:
    print(user)
# Out:
# {'name': 'Alice', 'rating': '5 ', 'feedback': 'Great product !! ', 'age': '25'}
# {'name': 'Bob', 'rating': 'four', 'feedback': 'ok but late Delivery', 'age': '30'}
# {'name': ' Charlie', 'rating': 'two', 'feedback': 'BAD EXPERIENCE '}
# {'name': 'Diana', 'feedback': 'Loved it!', 'rating': '5', 'age': '28'}
# {'name': 'Eve', 'rating': '3.5', 'feedback': 'Average - could be better', 'age': '20'}
# {'name': 'Alice', 'rating': '5', 'feedback': 'Great product again!', 'age': '25'}

# %%
# cleaning of data
## problem encountered
#  1. inconsistent data in rating
#  2. age missing
# 3. duplicate data

# %%
# 1. inconsistent data in rating
def clean_data(data):
    text_to_num={"one":1,"two":2,"three":3,"four":4,"five":5}
    for user in data:
        raw_rating=user[]
        print(user["rating"])
clean_data(data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 7
#       3     text_to_num={"one":1,"two":2,"three":3,"four":4,"five":5}
#       4     for user in data:
#       5         user["rating"]=text_to_num[user["rating"].strip().lower()]
#       6         print(user["rating"])
# ----> 7 clean_data(data)
#
# Cell In[16], line 5, in clean_data(data)
#       2 def clean_data(data):
#       3     text_to_num={"one":1,"two":2,"three":3,"four":4,"five":5}
#       4     for user in data:
# ----> 5         user["rating"]=text_to_num[user["rating"].strip().lower()]
#       6         print(user["rating"])
#
# KeyError: '5'
